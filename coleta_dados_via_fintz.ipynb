# %%
import pandas as pd
from datetime import datetime, timedelta
import time
import requests

# %%
URL_BASE = 'https://api.fintz.com.br'
api_key = 'varos_4a8d8a338da7bea2fb78540c73b0bfa7'
headers = { 'X-API-Key': api_key}

# %% [markdown]
# DOWNLOAD DE PREÇOS

# %%
params = {}

endpoint = URL_BASE + '/bolsa/b3/avista/cotacoes/historico/arquivos'
response = requests.get(endpoint, headers=headers, params=params)
print(response.json())
# Out:
# {'link': 'https://fintz-dagster.s3.amazonaws.com/unificado/historico_acoes.parquet?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=ASIAV2KWAOXUFHYH45LF%2F20240410%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240410T093111Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEPH%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMiJIMEYCIQDq58Lu2UCcrBHmk%2FHFJ02S%2FX8ZRmaiSQCxp1N1SnoGOwIhAIycFz0ziLyyhv4kBLDVeB1ikR2LhTt9yCsdwmoZoDMgKu4CCCsQARoMNDAwMTQ5MjE0Njk2IgwoyBqgHcfXdjWGNP8qywK6wkLhHSWkBszVcurAPz4ODXW6iotP%2Bail%2FRz%2BWTdB1dg9q5C%2F3Wm7As7oOYQzqqloO1nKA4CSukBUAZ9j%2BFpPs2SlP%2Ffg0qW7WB2pQks4gmnTO1TbG1rinO3E37K13%2Bmm5Y1azYbHOarZ8K65qviP9jK2JOOOvapGORyC%2BQcq2Hebz%2BGwPMz6THMRtW7fcQTWcB04ZYBTqRKyiAZBXhGm%2F1yb%2B3LAgYLxmfSPOgYGbzLchAu2NZe7bP8AjePHfeT4iur5qwe5bKZvf7i9hHu34MpZM%2BgtzV65EXUqiZUxD0tdkhxcqmtJe4ktEFqJcOy1nv55FM37XGjfMg3oaSn7qJbffhfWA75LPfo64R46m1qApe0Xj43Rhx6TaN5j9KrQ7fGB03Ue%2F3MmZtv08ix9bE78ILJ8iwQBKRahMCJDeOp2RtPS5CWMyeOEMNe42bAGOp0BF0IC6zAMJur
# ...

# %%
precos = pd.read_parquet('historico_acoes.parquet')

# %%
precos
# Out:
#               data  preco_abertura  preco_fechamento  preco_maximo  \
# 0       2010-01-04           35.53             35.99         36.23
# 1       2010-01-04            1.03              1.04          1.10
# 2       2010-01-04           16.89             17.02         17.05
# 3       2010-01-04           12.80             13.00         13.00
# 4       2010-01-04           10.70             10.64         10.75
# ...            ...             ...               ...           ...
# 1175149 2024-04-09           33.38             33.57         33.63
# 1175150 2024-04-09            7.59              7.65          7.69
# 1175151 2024-04-09            6.73              6.73          6.85
# 1175152 2024-04-09            1.90              1.86          1.99
# 1175153 2024-04-09            9.52              9.73          9.90
#
#          preco_medio  preco_minimo  quantidade_negociada  quantidade_negocios  \
# 0              35.61         35.00                158400                  626
# ...

# %% [markdown]
# DOWNLOAD DE ITENS CONTÁBEIS

# %%
params = { 'item': 'EBIT', 'tipoPeriodo': 'TRIMESTRAL' }

endpoint = URL_BASE + '/bolsa/b3/avista/itens-contabeis/point-in-time/arquivos'
response = requests.get(endpoint, headers=headers, params=params)
print(response.json())
# Out:
# {'link': 'https://fintz-dagster.s3.amazonaws.com/fontes/cvm/dfin/files/dfin_files/EBIT.parquet?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=ASIAV2KWAOXULIVZZHVX%2F20240410%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240410T090728Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEPH%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMiJIMEYCIQChwHYyQumm7i9yuxqCCmPSbzeMpfRoUgVaDicpCEeBcQIhAJG3TN7%2Fib3V%2BvpYIG9lHGHsH5%2F%2FeR%2BQ7FDJTo%2FfC0fSKu4CCCoQARoMNDAwMTQ5MjE0Njk2IgxPkxdVviKirP6yJsAqywJOQXtFM6%2BPxtFtUxIrouuyCzpJ27Op3xtCQijsiigQhDMbKBxj0cfabu03OCCrXfCRhTqIf7TXsh251zTXUIV3JubkoxGc78sBKZWeeQOie3oRg0UY7VDhOKkf9Rcpd7WkAR3IxHs73eNnl0iBhnTsS0Rxd2Hqm7biswJnTpWJvJ6UDrUUl6%2BP9dw5mBPx22J3Ql2GWuMYg%2BcJCdrWgf7nRTU%2Bgk9HLk2xvC66QhMmk9vbeC8SjmoJ5wIrvsT7RnpmP8Se6TYc3TDywPxe3vdOGLmQxsqOuw50QA6iN9gBWhd3wRpFL3SQ6IqMSrbQMfoRMUVjO4%2FKyiRsHK7RSxkPtXHrIcSD%2FEvadWZDycGYun6CJEa8T%2BP1Razz%2BrsRjOfJaEVSTbB7ywgrforM6tkmELjjjgefWOrFNIkJbQDnqqf%2BBG2VDKHtEWX6MMmt2bAGOp0
# ...

# %%
ebit = pd.read_parquet('EBIT.parquet')

# %%
ebit[ebit['ticker']=='BRKM5']
# Out:
#        ticker  item       data         valor
# 474410  BRKM5  EBIT 2011-05-12  5.058720e+08
# 474411  BRKM5  EBIT 2011-05-13  5.058720e+08
# 474412  BRKM5  EBIT 2011-05-14  5.058720e+08
# 474413  BRKM5  EBIT 2011-05-15  5.058720e+08
# 474414  BRKM5  EBIT 2011-05-16  5.058720e+08
# ...       ...   ...        ...           ...
# 479123  BRKM5  EBIT 2024-04-06  1.761828e+09
# 479124  BRKM5  EBIT 2024-04-07  1.761828e+09
# 479125  BRKM5  EBIT 2024-04-08  1.761828e+09
# 479126  BRKM5  EBIT 2024-04-09  1.761828e+09
# 479127  BRKM5  EBIT 2024-04-10  1.761828e+09
#
# [4718 rows x 4 columns]

# %%
params = { 'item': 'ReceitaLiquida', 'tipoPeriodo': 'TRIMESTRAL' }

endpoint = URL_BASE + '/bolsa/b3/avista/itens-contabeis/point-in-time/arquivos'
response = requests.get(endpoint, headers=headers, params=params)
print(response.json())
# Out:
# {'link': 'https://fintz-dagster.s3.amazonaws.com/fontes/cvm/dfin/files/dfin_files/ReceitaLiquida.parquet?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=ASIAV2KWAOXULIVZZHVX%2F20240410%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240410T090834Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEPH%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMiJIMEYCIQChwHYyQumm7i9yuxqCCmPSbzeMpfRoUgVaDicpCEeBcQIhAJG3TN7%2Fib3V%2BvpYIG9lHGHsH5%2F%2FeR%2BQ7FDJTo%2FfC0fSKu4CCCoQARoMNDAwMTQ5MjE0Njk2IgxPkxdVviKirP6yJsAqywJOQXtFM6%2BPxtFtUxIrouuyCzpJ27Op3xtCQijsiigQhDMbKBxj0cfabu03OCCrXfCRhTqIf7TXsh251zTXUIV3JubkoxGc78sBKZWeeQOie3oRg0UY7VDhOKkf9Rcpd7WkAR3IxHs73eNnl0iBhnTsS0Rxd2Hqm7biswJnTpWJvJ6UDrUUl6%2BP9dw5mBPx22J3Ql2GWuMYg%2BcJCdrWgf7nRTU%2Bgk9HLk2xvC66QhMmk9vbeC8SjmoJ5wIrvsT7RnpmP8Se6TYc3TDywPxe3vdOGLmQxsqOuw50QA6iN9gBWhd3wRpFL3SQ6IqMSrbQMfoRMUVjO4%2FKyiRsHK7RSxkPtXHrIcSD%2FEvadWZDycGYun6CJEa8T%2BP1Razz%2BrsRjOfJaEVSTbB7ywgrforM6tkmELjjjgefWOrFNIkJbQDnqqf%2BBG2VDKHtEWX6M
# ...

# %%
receita_liquida = pd.read_parquet('ReceitaLiquida.parquet')

# %%
receita_liquida[receita_liquida['ticker']=='CMIG4']
# Out:
#        ticker            item       data         valor
# 758318  CMIG4  ReceitaLiquida 2011-05-17  3.386587e+09
# 758319  CMIG4  ReceitaLiquida 2011-05-18  3.386587e+09
# 758320  CMIG4  ReceitaLiquida 2011-05-19  3.386587e+09
# 758321  CMIG4  ReceitaLiquida 2011-05-20  3.386587e+09
# 758322  CMIG4  ReceitaLiquida 2011-05-21  3.386587e+09
# ...       ...             ...        ...           ...
# 763026  CMIG4  ReceitaLiquida 2024-04-06  9.956686e+09
# 763027  CMIG4  ReceitaLiquida 2024-04-07  9.956686e+09
# 763028  CMIG4  ReceitaLiquida 2024-04-08  9.956686e+09
# 763029  CMIG4  ReceitaLiquida 2024-04-09  9.956686e+09
# 763030  CMIG4  ReceitaLiquida 2024-04-10  9.956686e+09
#
# [4713 rows x 4 columns]

# %%
params = { 'item': 'Custos', 'tipoPeriodo': 'TRIMESTRAL' }

endpoint = URL_BASE + '/bolsa/b3/avista/itens-contabeis/point-in-time/arquivos'
response = requests.get(endpoint, headers=headers, params=params)
print(response.json())
# Out:
# {'link': 'https://fintz-dagster.s3.amazonaws.com/fontes/cvm/dfin/files/dfin_files/Custos.parquet?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=ASIAV2KWAOXUFZ5O4OGJ%2F20240410%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240410T114650Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEPT%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMiJHMEUCIQCB1aiHZRgQg%2Bm1kdHfxTZWZ3Z%2F%2FDc32EkBwTrUfRcE8QIgC26UfNvzhUDTGJbjAKldXi1Nn2kJlumszxYknhk0rMQq7gIILRABGgw0MDAxNDkyMTQ2OTYiDGdOnrNI3bNn8Kwm8yrLAt7y4%2FNr0KQ15WRa1%2BoeKxA%2F81zheN9KYou%2B7xbrLj0OwblUNKdhEBvcwK%2FGwbc7bZeVWVzw%2Bx%2FeF5QvvP%2FXRJCaqq8gFSrpmXUWPxboCOGsk9SL294eJl0DWOyVbA3RHfDZUEatD1G511ReKivXwAcgMgrT9KGJ0QAPSgSYbmgjEP805qYszws0S8Xx8OJ5axS8ALJdSq3VNNCVPqfaVSSPQGL58SUlytt1wPLt5wOUZAKFCnlzTs7G1A8jDxZ0hEGSZJj2LNOUarBBlIXzdWj%2BpAPdmKtImCvi1B74f%2FYgT5DAfj7SbJmqwA2E%2FXzspdWSI7FHYsKpdk7Mu0Pu5pYGEUYn%2F1M4fSNhDVluc0KEd%2BRpTHtOw9grmr8aR092nw9GAB9f%2FCj9NNK72tTxMSmY176KL5AoQ30QlBoMKmmtzlOTcnoHwzxbAhYwo%2Fj
# ...

# %%
custos = pd.read_parquet('Custos.parquet')

# %%
custos[custos['ticker']=='ARZZ3']
# Out:
#        ticker    item       data        valor
# 151064  ARZZ3  Custos 2011-05-11  -82150000.0
# 151065  ARZZ3  Custos 2011-05-12  -82150000.0
# 151066  ARZZ3  Custos 2011-05-13  -82150000.0
# 151067  ARZZ3  Custos 2011-05-14  -82150000.0
# 151068  ARZZ3  Custos 2011-05-15  -82150000.0
# ...       ...     ...        ...          ...
# 155778  ARZZ3  Custos 2024-04-06 -627634000.0
# 155779  ARZZ3  Custos 2024-04-07 -627634000.0
# 155780  ARZZ3  Custos 2024-04-08 -627634000.0
# 155781  ARZZ3  Custos 2024-04-09 -627634000.0
# 155782  ARZZ3  Custos 2024-04-10 -627634000.0
#
# [4719 rows x 4 columns]

# %%
params = { 'item': 'LucroLiquido', 'tipoPeriodo': 'TRIMESTRAL' }

endpoint = URL_BASE + '/bolsa/b3/avista/itens-contabeis/point-in-time/arquivos'
response = requests.get(endpoint, headers=headers, params=params)
print(response.json())
# Out:
# {'link': 'https://fintz-dagster.s3.amazonaws.com/fontes/cvm/dfin/files/dfin_files/LucroLiquido.parquet?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=ASIAV2KWAOXUF4GUXCH3%2F20240410%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240410T092314Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEPH%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMiJGMEQCIAYh6q%2F7opcvSNN6%2BZDrdmCJhdwmLv1j%2B0j7Nz2VwBj5AiBEH2IXQ1oLxi2WdJSoYKp1GD4Oq09Xz%2BhQOyKnH00KniruAggrEAEaDDQwMDE0OTIxNDY5NiIMB3YYY4hqdb8pB8pdKssC8zSUa1N%2BEIejsFfGzf65eTQdydVnJwfhD2%2FqTCWtA98yDjZX4NXkGPWrXzBxwU9CUiTBRxOd7NLNoH%2FzZpavVdEbuG4%2FIsxuajo6QpmwoAdPZNdJYWzXnDne3kvEnX5jDcWrpTwQdd5dVj4aPwvGgtjb%2FDCiDCHKhI1BJbYoav%2BzTP9oBpyFujTCAtB7%2Fd9EWaFK%2FNuTPeAeC55%2BCOURso9BgXbveJK2Ab8eaZxC3%2BW%2B4TStMcivRhvvBOsALqc2kZAw0oNt4EZEKD0CxwGRGZuv1pN44rD1a0hxGErHGECvlsVxqjKTXvz1gdUrBYQBLa%2FHlNTGqjkrMlcrGrDGG2xlZajRevB7mjUHFhbPqdkyvNxRrN%2F3uOfGbUSWXHDGDGlRQL3Cgr1TXotOCIj2BDu0GY38Nh%2BuH%2BoLswq%2B%2BOYpAo8RsB7
# ...

# %%
lucro_liquido = pd.read_parquet('LucroLiquido.parquet')

# %%
lucro_liquido[lucro_liquido['ticker']=='LREN3']
# Out:
#         ticker          item       data        valor
# 1751288  LREN3  LucroLiquido 2011-04-28   47587000.0
# 1751289  LREN3  LucroLiquido 2011-04-29   47587000.0
# 1751290  LREN3  LucroLiquido 2011-04-30   47587000.0
# 1751291  LREN3  LucroLiquido 2011-05-01   47587000.0
# 1751292  LREN3  LucroLiquido 2011-05-02   47587000.0
# ...        ...           ...        ...          ...
# 1756015  LREN3  LucroLiquido 2024-04-06  526891000.0
# 1756016  LREN3  LucroLiquido 2024-04-07  526891000.0
# 1756017  LREN3  LucroLiquido 2024-04-08  526891000.0
# 1756018  LREN3  LucroLiquido 2024-04-09  526891000.0
# 1756019  LREN3  LucroLiquido 2024-04-10  526891000.0
#
# [4732 rows x 4 columns]

# %%
params = { 'item': 'AtivoCirculante', 'tipoPeriodo': 'TRIMESTRAL' }

endpoint = URL_BASE + '/bolsa/b3/avista/itens-contabeis/point-in-time/arquivos'
response = requests.get(endpoint, headers=headers, params=params)
print(response.json())
# Out:
# {'link': 'https://fintz-dagster.s3.amazonaws.com/fontes/cvm/dfin/files/dfin_files/AtivoCirculante.parquet?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=ASIAV2KWAOXUF4GUXCH3%2F20240410%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240410T092323Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEPH%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMiJGMEQCIAYh6q%2F7opcvSNN6%2BZDrdmCJhdwmLv1j%2B0j7Nz2VwBj5AiBEH2IXQ1oLxi2WdJSoYKp1GD4Oq09Xz%2BhQOyKnH00KniruAggrEAEaDDQwMDE0OTIxNDY5NiIMB3YYY4hqdb8pB8pdKssC8zSUa1N%2BEIejsFfGzf65eTQdydVnJwfhD2%2FqTCWtA98yDjZX4NXkGPWrXzBxwU9CUiTBRxOd7NLNoH%2FzZpavVdEbuG4%2FIsxuajo6QpmwoAdPZNdJYWzXnDne3kvEnX5jDcWrpTwQdd5dVj4aPwvGgtjb%2FDCiDCHKhI1BJbYoav%2BzTP9oBpyFujTCAtB7%2Fd9EWaFK%2FNuTPeAeC55%2BCOURso9BgXbveJK2Ab8eaZxC3%2BW%2B4TStMcivRhvvBOsALqc2kZAw0oNt4EZEKD0CxwGRGZuv1pN44rD1a0hxGErHGECvlsVxqjKTXvz1gdUrBYQBLa%2FHlNTGqjkrMlcrGrDGG2xlZajRevB7mjUHFhbPqdkyvNxRrN%2F3uOfGbUSWXHDGDGlRQL3Cgr1TXotOCIj2BDu0GY38Nh%2BuH%2BoLswq%2B%2BOYpAo8R
# ...

# %%
ativo_circulante = pd.read_parquet('AtivoCirculante.parquet')

# %%
ativo_circulante[ativo_circulante['ticker']=='CYRE3']
# Out:
#        ticker             item       data         valor
# 799790  CYRE3  AtivoCirculante 2011-03-28  8.189985e+09
# 799791  CYRE3  AtivoCirculante 2011-03-29  8.189985e+09
# 799792  CYRE3  AtivoCirculante 2011-03-30  8.189985e+09
# 799793  CYRE3  AtivoCirculante 2011-03-31  8.189985e+09
# 799794  CYRE3  AtivoCirculante 2011-04-01  8.189985e+09
# ...       ...              ...        ...           ...
# 804548  CYRE3  AtivoCirculante 2024-04-06  9.768408e+09
# 804549  CYRE3  AtivoCirculante 2024-04-07  9.768408e+09
# 804550  CYRE3  AtivoCirculante 2024-04-08  9.768408e+09
# 804551  CYRE3  AtivoCirculante 2024-04-09  9.768408e+09
# 804552  CYRE3  AtivoCirculante 2024-04-10  9.768408e+09
#
# [4763 rows x 4 columns]

# %%
params = { 'item': 'AtivoNaoCirculante', 'tipoPeriodo': 'TRIMESTRAL' }

endpoint = URL_BASE + '/bolsa/b3/avista/itens-contabeis/point-in-time/arquivos'
response = requests.get(endpoint, headers=headers, params=params)
print(response.json())
# Out:
# {'link': 'https://fintz-dagster.s3.amazonaws.com/fontes/cvm/dfin/files/dfin_files/AtivoNaoCirculante.parquet?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=ASIAV2KWAOXUF4GUXCH3%2F20240410%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240410T092355Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEPH%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMiJGMEQCIAYh6q%2F7opcvSNN6%2BZDrdmCJhdwmLv1j%2B0j7Nz2VwBj5AiBEH2IXQ1oLxi2WdJSoYKp1GD4Oq09Xz%2BhQOyKnH00KniruAggrEAEaDDQwMDE0OTIxNDY5NiIMB3YYY4hqdb8pB8pdKssC8zSUa1N%2BEIejsFfGzf65eTQdydVnJwfhD2%2FqTCWtA98yDjZX4NXkGPWrXzBxwU9CUiTBRxOd7NLNoH%2FzZpavVdEbuG4%2FIsxuajo6QpmwoAdPZNdJYWzXnDne3kvEnX5jDcWrpTwQdd5dVj4aPwvGgtjb%2FDCiDCHKhI1BJbYoav%2BzTP9oBpyFujTCAtB7%2Fd9EWaFK%2FNuTPeAeC55%2BCOURso9BgXbveJK2Ab8eaZxC3%2BW%2B4TStMcivRhvvBOsALqc2kZAw0oNt4EZEKD0CxwGRGZuv1pN44rD1a0hxGErHGECvlsVxqjKTXvz1gdUrBYQBLa%2FHlNTGqjkrMlcrGrDGG2xlZajRevB7mjUHFhbPqdkyvNxRrN%2F3uOfGbUSWXHDGDGlRQL3Cgr1TXotOCIj2BDu0GY38Nh%2BuH%2BoLswq%2B%2BOYpA
# ...

# %%
ativo_nao_circulante = pd.read_parquet('AtivoNaoCirculante.parquet')

# %%
ativo_nao_circulante[ativo_nao_circulante['ticker']=='HAPV3']
# Out:
#         ticker                item       data         valor
# 1306708  HAPV3  AtivoNaoCirculante 2018-04-24  1.097170e+09
# 1306709  HAPV3  AtivoNaoCirculante 2018-04-25  1.097170e+09
# 1306710  HAPV3  AtivoNaoCirculante 2018-04-26  1.097170e+09
# 1306711  HAPV3  AtivoNaoCirculante 2018-04-27  1.097170e+09
# 1306712  HAPV3  AtivoNaoCirculante 2018-04-28  1.097170e+09
# ...        ...                 ...        ...           ...
# 1308882  HAPV3  AtivoNaoCirculante 2024-04-06  6.462859e+10
# 1308883  HAPV3  AtivoNaoCirculante 2024-04-07  6.462859e+10
# 1308884  HAPV3  AtivoNaoCirculante 2024-04-08  6.462859e+10
# 1308885  HAPV3  AtivoNaoCirculante 2024-04-09  6.462859e+10
# 1308886  HAPV3  AtivoNaoCirculante 2024-04-10  6.462859e+10
#
# [2179 rows x 4 columns]

# %%
params = { 'item': 'AtivoTotal', 'tipoPeriodo': 'TRIMESTRAL' }

endpoint = URL_BASE + '/bolsa/b3/avista/itens-contabeis/point-in-time/arquivos'
response = requests.get(endpoint, headers=headers, params=params)
print(response.json())
# Out:
# {'link': 'https://fintz-dagster.s3.amazonaws.com/fontes/cvm/dfin/files/dfin_files/AtivoTotal.parquet?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=ASIAV2KWAOXUF4GUXCH3%2F20240410%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240410T092420Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEPH%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMiJGMEQCIAYh6q%2F7opcvSNN6%2BZDrdmCJhdwmLv1j%2B0j7Nz2VwBj5AiBEH2IXQ1oLxi2WdJSoYKp1GD4Oq09Xz%2BhQOyKnH00KniruAggrEAEaDDQwMDE0OTIxNDY5NiIMB3YYY4hqdb8pB8pdKssC8zSUa1N%2BEIejsFfGzf65eTQdydVnJwfhD2%2FqTCWtA98yDjZX4NXkGPWrXzBxwU9CUiTBRxOd7NLNoH%2FzZpavVdEbuG4%2FIsxuajo6QpmwoAdPZNdJYWzXnDne3kvEnX5jDcWrpTwQdd5dVj4aPwvGgtjb%2FDCiDCHKhI1BJbYoav%2BzTP9oBpyFujTCAtB7%2Fd9EWaFK%2FNuTPeAeC55%2BCOURso9BgXbveJK2Ab8eaZxC3%2BW%2B4TStMcivRhvvBOsALqc2kZAw0oNt4EZEKD0CxwGRGZuv1pN44rD1a0hxGErHGECvlsVxqjKTXvz1gdUrBYQBLa%2FHlNTGqjkrMlcrGrDGG2xlZajRevB7mjUHFhbPqdkyvNxRrN%2F3uOfGbUSWXHDGDGlRQL3Cgr1TXotOCIj2BDu0GY38Nh%2BuH%2BoLswq%2B%2BOYpAo8RsB7X%
# ...

# %%
ativo_total = pd.read_parquet('AtivoTotal.parquet')

# %%
ativo_total[ativo_total['ticker']=='MRVE3']
# Out:
#         ticker        item       data         valor
# 1931718  MRVE3  AtivoTotal 2011-03-30  6.791338e+09
# 1931719  MRVE3  AtivoTotal 2011-03-31  6.791338e+09
# 1931720  MRVE3  AtivoTotal 2011-04-01  6.791338e+09
# 1931721  MRVE3  AtivoTotal 2011-04-02  6.791338e+09
# 1931722  MRVE3  AtivoTotal 2011-04-03  6.791338e+09
# ...        ...         ...        ...           ...
# 1936474  MRVE3  AtivoTotal 2024-04-06  2.507170e+10
# 1936475  MRVE3  AtivoTotal 2024-04-07  2.507170e+10
# 1936476  MRVE3  AtivoTotal 2024-04-08  2.507170e+10
# 1936477  MRVE3  AtivoTotal 2024-04-09  2.507170e+10
# 1936478  MRVE3  AtivoTotal 2024-04-10  2.507170e+10
#
# [4761 rows x 4 columns]

# %%
params = { 'item': 'CaixaEquivalentes', 'tipoPeriodo': 'TRIMESTRAL' }

endpoint = URL_BASE + '/bolsa/b3/avista/itens-contabeis/point-in-time/arquivos'
response = requests.get(endpoint, headers=headers, params=params)
print(response.json())
# Out:
# {'link': 'https://fintz-dagster.s3.amazonaws.com/fontes/cvm/dfin/files/dfin_files/CaixaEquivalentes.parquet?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=ASIAV2KWAOXUF4GUXCH3%2F20240410%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240410T092454Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEPH%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMiJGMEQCIAYh6q%2F7opcvSNN6%2BZDrdmCJhdwmLv1j%2B0j7Nz2VwBj5AiBEH2IXQ1oLxi2WdJSoYKp1GD4Oq09Xz%2BhQOyKnH00KniruAggrEAEaDDQwMDE0OTIxNDY5NiIMB3YYY4hqdb8pB8pdKssC8zSUa1N%2BEIejsFfGzf65eTQdydVnJwfhD2%2FqTCWtA98yDjZX4NXkGPWrXzBxwU9CUiTBRxOd7NLNoH%2FzZpavVdEbuG4%2FIsxuajo6QpmwoAdPZNdJYWzXnDne3kvEnX5jDcWrpTwQdd5dVj4aPwvGgtjb%2FDCiDCHKhI1BJbYoav%2BzTP9oBpyFujTCAtB7%2Fd9EWaFK%2FNuTPeAeC55%2BCOURso9BgXbveJK2Ab8eaZxC3%2BW%2B4TStMcivRhvvBOsALqc2kZAw0oNt4EZEKD0CxwGRGZuv1pN44rD1a0hxGErHGECvlsVxqjKTXvz1gdUrBYQBLa%2FHlNTGqjkrMlcrGrDGG2xlZajRevB7mjUHFhbPqdkyvNxRrN%2F3uOfGbUSWXHDGDGlRQL3Cgr1TXotOCIj2BDu0GY38Nh%2BuH%2BoLswq%2B%2BOYpAo
# ...

# %%
caixa = pd.read_parquet('CaixaEquivalentes.parquet')

# %%
caixa[caixa['ticker']=='B3SA3']
# Out:
#        ticker               item       data         valor
# 187328  B3SA3  CaixaEquivalentes 2011-02-17  1.040170e+08
# 187329  B3SA3  CaixaEquivalentes 2011-02-18  1.040170e+08
# 187330  B3SA3  CaixaEquivalentes 2011-02-19  1.040170e+08
# 187331  B3SA3  CaixaEquivalentes 2011-02-20  1.040170e+08
# 187332  B3SA3  CaixaEquivalentes 2011-02-21  1.040170e+08
# ...       ...                ...        ...           ...
# 192125  B3SA3  CaixaEquivalentes 2024-04-06  1.788906e+09
# 192126  B3SA3  CaixaEquivalentes 2024-04-07  1.788906e+09
# 192127  B3SA3  CaixaEquivalentes 2024-04-08  1.788906e+09
# 192128  B3SA3  CaixaEquivalentes 2024-04-09  1.788906e+09
# 192129  B3SA3  CaixaEquivalentes 2024-04-10  1.788906e+09
#
# [4802 rows x 4 columns]

# %%
params = { 'item': 'DividaBruta', 'tipoPeriodo': 'TRIMESTRAL' }

endpoint = URL_BASE + '/bolsa/b3/avista/itens-contabeis/point-in-time/arquivos'
response = requests.get(endpoint, headers=headers, params=params)
print(response.json())
# Out:
# {'link': 'https://fintz-dagster.s3.amazonaws.com/fontes/cvm/dfin/files/dfin_files/DividaBruta.parquet?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=ASIAV2KWAOXUPWVZIM33%2F20240410%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240410T104930Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEPP%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMiJGMEQCIHEcG2W%2Fbd1rB8M6UEu50ILnhY2MbVTRj%2FeuiHJrTEomAiBzBTNTmgmsKWp5LjzneeCsKr7ccPbVwbCU7fvlz8m%2FDSruAggsEAEaDDQwMDE0OTIxNDY5NiIMlTEvDVnhuXup0YDPKssCWB0qLeLWY6Behyux47Jzq8I%2BlwV3aYz4hvReZ5ABhb4tUJ7s5PWJwDzOt8eKA4O5BM3czlPhki5yLIdJJkIt7pCVYsCh8bJiEaolVZQyOo7A%2FaeaS9hvmQxw0ta7tW4Y9kWvL6OKkLxr50nz2GB2PDgSEU9lX%2BZLrK3iXPTALIKqBO%2BDMw353ZzOr66Q%2B3x2X%2FY9A1%2BseheDfRE6Bo2rAcfg%2BzICIM3SERy020Spa8hTwHg%2Fu7Nuu47XZDkY4JCuefeULFC16i4vIMjt3XKGB3vrDvRv1pOEs2Wp7DSkMFDrekwCjWSEhW0QqbckBpoKow9%2BJNfSb0M94iOKi3zqn8ecx5ulQhymHAIqx2Uu9lYWjtUXQGWxGs99NfIt71A8KdmH4jTrsbBVybu7ADuUrN9rQUdvr5R%2FvXFkp1liWDObTlPAozgTgq%2B5VzCb3dmw
# ...

# %%
divida_bruta = pd.read_parquet('DividaBruta.parquet')

# %%
divida_bruta[divida_bruta['ticker']=='MGLU3']
# Out:
#         ticker         item       data         valor
# 1645509  MGLU3  DividaBruta 2011-05-05  7.748730e+08
# 1645510  MGLU3  DividaBruta 2011-05-06  7.748730e+08
# 1645511  MGLU3  DividaBruta 2011-05-07  7.748730e+08
# 1645512  MGLU3  DividaBruta 2011-05-08  7.748730e+08
# 1645513  MGLU3  DividaBruta 2011-05-09  7.748730e+08
# ...        ...          ...        ...           ...
# 1650229  MGLU3  DividaBruta 2024-04-06  7.354855e+09
# 1650230  MGLU3  DividaBruta 2024-04-07  7.354855e+09
# 1650231  MGLU3  DividaBruta 2024-04-08  7.354855e+09
# 1650232  MGLU3  DividaBruta 2024-04-09  7.354855e+09
# 1650233  MGLU3  DividaBruta 2024-04-10  7.354855e+09
#
# [4725 rows x 4 columns]

# %%
params = { 'item': 'DividaLiquida', 'tipoPeriodo': 'TRIMESTRAL' }

endpoint = URL_BASE + '/bolsa/b3/avista/itens-contabeis/point-in-time/arquivos'
response = requests.get(endpoint, headers=headers, params=params)
print(response.json())
# Out:
# {'link': 'https://fintz-dagster.s3.amazonaws.com/fontes/cvm/dfin/files/dfin_files/DividaLiquida.parquet?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=ASIAV2KWAOXUPWVZIM33%2F20240410%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240410T104951Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEPP%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMiJGMEQCIHEcG2W%2Fbd1rB8M6UEu50ILnhY2MbVTRj%2FeuiHJrTEomAiBzBTNTmgmsKWp5LjzneeCsKr7ccPbVwbCU7fvlz8m%2FDSruAggsEAEaDDQwMDE0OTIxNDY5NiIMlTEvDVnhuXup0YDPKssCWB0qLeLWY6Behyux47Jzq8I%2BlwV3aYz4hvReZ5ABhb4tUJ7s5PWJwDzOt8eKA4O5BM3czlPhki5yLIdJJkIt7pCVYsCh8bJiEaolVZQyOo7A%2FaeaS9hvmQxw0ta7tW4Y9kWvL6OKkLxr50nz2GB2PDgSEU9lX%2BZLrK3iXPTALIKqBO%2BDMw353ZzOr66Q%2B3x2X%2FY9A1%2BseheDfRE6Bo2rAcfg%2BzICIM3SERy020Spa8hTwHg%2Fu7Nuu47XZDkY4JCuefeULFC16i4vIMjt3XKGB3vrDvRv1pOEs2Wp7DSkMFDrekwCjWSEhW0QqbckBpoKow9%2BJNfSb0M94iOKi3zqn8ecx5ulQhymHAIqx2Uu9lYWjtUXQGWxGs99NfIt71A8KdmH4jTrsbBVybu7ADuUrN9rQUdvr5R%2FvXFkp1liWDObTlPAozgTgq%2B5VzCb3d
# ...

# %%
divida_liquida = pd.read_parquet('DividaLiquida.parquet')

# %%
divida_liquida[divida_liquida['ticker']=='BHIA3']
# Out:
#        ticker           item       data         valor
# 230299  BHIA3  DividaLiquida 2011-02-24  1.275301e+09
# 230300  BHIA3  DividaLiquida 2011-02-25  1.275301e+09
# 230301  BHIA3  DividaLiquida 2011-02-26  1.275301e+09
# 230302  BHIA3  DividaLiquida 2011-02-27  1.275301e+09
# 230303  BHIA3  DividaLiquida 2011-02-28  1.275301e+09
# ...       ...            ...        ...           ...
# 235089  BHIA3  DividaLiquida 2024-04-06  6.386000e+09
# 235090  BHIA3  DividaLiquida 2024-04-07  6.386000e+09
# 235091  BHIA3  DividaLiquida 2024-04-08  6.386000e+09
# 235092  BHIA3  DividaLiquida 2024-04-09  6.386000e+09
# 235093  BHIA3  DividaLiquida 2024-04-10  6.386000e+09
#
# [4795 rows x 4 columns]

# %%
params = { 'item': 'EBITDA', 'tipoPeriodo': 'TRIMESTRAL' }

endpoint = URL_BASE + '/bolsa/b3/avista/itens-contabeis/point-in-time/arquivos'
response = requests.get(endpoint, headers=headers, params=params)
print(response.json())
# Out:
# {'link': 'https://fintz-dagster.s3.amazonaws.com/fontes/cvm/dfin/files/dfin_files/EBITDA.parquet?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=ASIAV2KWAOXUPWVZIM33%2F20240410%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240410T105044Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEPP%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMiJGMEQCIHEcG2W%2Fbd1rB8M6UEu50ILnhY2MbVTRj%2FeuiHJrTEomAiBzBTNTmgmsKWp5LjzneeCsKr7ccPbVwbCU7fvlz8m%2FDSruAggsEAEaDDQwMDE0OTIxNDY5NiIMlTEvDVnhuXup0YDPKssCWB0qLeLWY6Behyux47Jzq8I%2BlwV3aYz4hvReZ5ABhb4tUJ7s5PWJwDzOt8eKA4O5BM3czlPhki5yLIdJJkIt7pCVYsCh8bJiEaolVZQyOo7A%2FaeaS9hvmQxw0ta7tW4Y9kWvL6OKkLxr50nz2GB2PDgSEU9lX%2BZLrK3iXPTALIKqBO%2BDMw353ZzOr66Q%2B3x2X%2FY9A1%2BseheDfRE6Bo2rAcfg%2BzICIM3SERy020Spa8hTwHg%2Fu7Nuu47XZDkY4JCuefeULFC16i4vIMjt3XKGB3vrDvRv1pOEs2Wp7DSkMFDrekwCjWSEhW0QqbckBpoKow9%2BJNfSb0M94iOKi3zqn8ecx5ulQhymHAIqx2Uu9lYWjtUXQGWxGs99NfIt71A8KdmH4jTrsbBVybu7ADuUrN9rQUdvr5R%2FvXFkp1liWDObTlPAozgTgq%2B5VzCb3dmwBjqfA
# ...

# %%
ebitda = pd.read_parquet('EBITDA.parquet')

# %%
ebitda[ebitda['ticker']=='SUZB3']
# Out:
#         ticker    item       data         valor
# 2353784  SUZB3  EBITDA 2011-05-11  3.434120e+08
# 2353785  SUZB3  EBITDA 2011-05-12  3.434120e+08
# 2353786  SUZB3  EBITDA 2011-05-13  3.434120e+08
# 2353787  SUZB3  EBITDA 2011-05-14  3.434120e+08
# 2353788  SUZB3  EBITDA 2011-05-15  3.434120e+08
# ...        ...     ...        ...           ...
# 2358498  SUZB3  EBITDA 2024-04-06  4.959323e+09
# 2358499  SUZB3  EBITDA 2024-04-07  4.959323e+09
# 2358500  SUZB3  EBITDA 2024-04-08  4.959323e+09
# 2358501  SUZB3  EBITDA 2024-04-09  4.959323e+09
# 2358502  SUZB3  EBITDA 2024-04-10  4.959323e+09
#
# [4719 rows x 4 columns]

# %%
params = { 'item': 'PassivoCirculante', 'tipoPeriodo': 'TRIMESTRAL' }

endpoint = URL_BASE + '/bolsa/b3/avista/itens-contabeis/point-in-time/arquivos'
response = requests.get(endpoint, headers=headers, params=params)
print(response.json())
# Out:
# {'link': 'https://fintz-dagster.s3.amazonaws.com/fontes/cvm/dfin/files/dfin_files/PassivoCirculante.parquet?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=ASIAV2KWAOXUPWVZIM33%2F20240410%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240410T105338Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEPP%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMiJGMEQCIHEcG2W%2Fbd1rB8M6UEu50ILnhY2MbVTRj%2FeuiHJrTEomAiBzBTNTmgmsKWp5LjzneeCsKr7ccPbVwbCU7fvlz8m%2FDSruAggsEAEaDDQwMDE0OTIxNDY5NiIMlTEvDVnhuXup0YDPKssCWB0qLeLWY6Behyux47Jzq8I%2BlwV3aYz4hvReZ5ABhb4tUJ7s5PWJwDzOt8eKA4O5BM3czlPhki5yLIdJJkIt7pCVYsCh8bJiEaolVZQyOo7A%2FaeaS9hvmQxw0ta7tW4Y9kWvL6OKkLxr50nz2GB2PDgSEU9lX%2BZLrK3iXPTALIKqBO%2BDMw353ZzOr66Q%2B3x2X%2FY9A1%2BseheDfRE6Bo2rAcfg%2BzICIM3SERy020Spa8hTwHg%2Fu7Nuu47XZDkY4JCuefeULFC16i4vIMjt3XKGB3vrDvRv1pOEs2Wp7DSkMFDrekwCjWSEhW0QqbckBpoKow9%2BJNfSb0M94iOKi3zqn8ecx5ulQhymHAIqx2Uu9lYWjtUXQGWxGs99NfIt71A8KdmH4jTrsbBVybu7ADuUrN9rQUdvr5R%2FvXFkp1liWDObTlPAozgTgq%2B5Vz
# ...

# %%
passivo_circulante = pd.read_parquet('PassivoCirculante.parquet')

# %%
passivo_circulante[passivo_circulante['ticker']=='TRPL4']
# Out:
#         ticker               item       data         valor
# 2586538  TRPL4  PassivoCirculante 2011-03-28  8.140490e+08
# 2586539  TRPL4  PassivoCirculante 2011-03-29  8.140490e+08
# 2586540  TRPL4  PassivoCirculante 2011-03-30  8.140490e+08
# 2586541  TRPL4  PassivoCirculante 2011-03-31  8.140490e+08
# 2586542  TRPL4  PassivoCirculante 2011-04-01  8.140490e+08
# ...        ...                ...        ...           ...
# 2591296  TRPL4  PassivoCirculante 2024-04-06  2.444736e+09
# 2591297  TRPL4  PassivoCirculante 2024-04-07  2.444736e+09
# 2591298  TRPL4  PassivoCirculante 2024-04-08  2.444736e+09
# 2591299  TRPL4  PassivoCirculante 2024-04-09  2.444736e+09
# 2591300  TRPL4  PassivoCirculante 2024-04-10  2.444736e+09
#
# [4763 rows x 4 columns]

# %%
params = { 'item': 'PassivoNaoCirculante', 'tipoPeriodo': 'TRIMESTRAL' }

endpoint = URL_BASE + '/bolsa/b3/avista/itens-contabeis/point-in-time/arquivos'
response = requests.get(endpoint, headers=headers, params=params)
print(response.json())
# Out:
# {'link': 'https://fintz-dagster.s3.amazonaws.com/fontes/cvm/dfin/files/dfin_files/PassivoNaoCirculante.parquet?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=ASIAV2KWAOXUPWVZIM33%2F20240410%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240410T105405Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEPP%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMiJGMEQCIHEcG2W%2Fbd1rB8M6UEu50ILnhY2MbVTRj%2FeuiHJrTEomAiBzBTNTmgmsKWp5LjzneeCsKr7ccPbVwbCU7fvlz8m%2FDSruAggsEAEaDDQwMDE0OTIxNDY5NiIMlTEvDVnhuXup0YDPKssCWB0qLeLWY6Behyux47Jzq8I%2BlwV3aYz4hvReZ5ABhb4tUJ7s5PWJwDzOt8eKA4O5BM3czlPhki5yLIdJJkIt7pCVYsCh8bJiEaolVZQyOo7A%2FaeaS9hvmQxw0ta7tW4Y9kWvL6OKkLxr50nz2GB2PDgSEU9lX%2BZLrK3iXPTALIKqBO%2BDMw353ZzOr66Q%2B3x2X%2FY9A1%2BseheDfRE6Bo2rAcfg%2BzICIM3SERy020Spa8hTwHg%2Fu7Nuu47XZDkY4JCuefeULFC16i4vIMjt3XKGB3vrDvRv1pOEs2Wp7DSkMFDrekwCjWSEhW0QqbckBpoKow9%2BJNfSb0M94iOKi3zqn8ecx5ulQhymHAIqx2Uu9lYWjtUXQGWxGs99NfIt71A8KdmH4jTrsbBVybu7ADuUrN9rQUdvr5R%2FvXFkp1liWDObTlPAozgTgq%2B
# ...

# %%
passivo_nao_circulante = pd.read_parquet('PassivoNaoCirculante.parquet')

# %%
passivo_nao_circulante[passivo_nao_circulante['ticker']=='EQTL3']
# Out:
#         ticker                  item       data         valor
# 1066464  EQTL3  PassivoNaoCirculante 2011-03-30  1.341791e+09
# 1066465  EQTL3  PassivoNaoCirculante 2011-03-31  1.341791e+09
# 1066466  EQTL3  PassivoNaoCirculante 2011-04-01  1.341791e+09
# 1066467  EQTL3  PassivoNaoCirculante 2011-04-02  1.341791e+09
# 1066468  EQTL3  PassivoNaoCirculante 2011-04-03  1.341791e+09
# ...        ...                   ...        ...           ...
# 1071220  EQTL3  PassivoNaoCirculante 2024-04-06  6.021041e+10
# 1071221  EQTL3  PassivoNaoCirculante 2024-04-07  6.021041e+10
# 1071222  EQTL3  PassivoNaoCirculante 2024-04-08  6.021041e+10
# 1071223  EQTL3  PassivoNaoCirculante 2024-04-09  6.021041e+10
# 1071224  EQTL3  PassivoNaoCirculante 2024-04-10  6.021041e+10
#
# [4761 rows x 4 columns]

# %%
params = { 'item': 'PassivoTotal', 'tipoPeriodo': 'TRIMESTRAL' }

endpoint = URL_BASE + '/bolsa/b3/avista/itens-contabeis/point-in-time/arquivos'
response = requests.get(endpoint, headers=headers, params=params)
print(response.json())
# Out:
# {'link': 'https://fintz-dagster.s3.amazonaws.com/fontes/cvm/dfin/files/dfin_files/PassivoTotal.parquet?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=ASIAV2KWAOXUPWVZIM33%2F20240410%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240410T105425Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEPP%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMiJGMEQCIHEcG2W%2Fbd1rB8M6UEu50ILnhY2MbVTRj%2FeuiHJrTEomAiBzBTNTmgmsKWp5LjzneeCsKr7ccPbVwbCU7fvlz8m%2FDSruAggsEAEaDDQwMDE0OTIxNDY5NiIMlTEvDVnhuXup0YDPKssCWB0qLeLWY6Behyux47Jzq8I%2BlwV3aYz4hvReZ5ABhb4tUJ7s5PWJwDzOt8eKA4O5BM3czlPhki5yLIdJJkIt7pCVYsCh8bJiEaolVZQyOo7A%2FaeaS9hvmQxw0ta7tW4Y9kWvL6OKkLxr50nz2GB2PDgSEU9lX%2BZLrK3iXPTALIKqBO%2BDMw353ZzOr66Q%2B3x2X%2FY9A1%2BseheDfRE6Bo2rAcfg%2BzICIM3SERy020Spa8hTwHg%2Fu7Nuu47XZDkY4JCuefeULFC16i4vIMjt3XKGB3vrDvRv1pOEs2Wp7DSkMFDrekwCjWSEhW0QqbckBpoKow9%2BJNfSb0M94iOKi3zqn8ecx5ulQhymHAIqx2Uu9lYWjtUXQGWxGs99NfIt71A8KdmH4jTrsbBVybu7ADuUrN9rQUdvr5R%2FvXFkp1liWDObTlPAozgTgq%2B5VzCb3dm
# ...

# %%
passivo_total = pd.read_parquet('PassivoTotal.parquet')

# %%
passivo_total[passivo_total['ticker']=='ECOR3']
# Out:
#         ticker          item       data         valor
# 1077884  ECOR3  PassivoTotal 2011-03-22  4.165776e+09
# 1077885  ECOR3  PassivoTotal 2011-03-23  4.165776e+09
# 1077886  ECOR3  PassivoTotal 2011-03-24  4.165776e+09
# 1077887  ECOR3  PassivoTotal 2011-03-25  4.165776e+09
# 1077888  ECOR3  PassivoTotal 2011-03-26  4.165776e+09
# ...        ...           ...        ...           ...
# 1082648  ECOR3  PassivoTotal 2024-04-06  2.595990e+10
# 1082649  ECOR3  PassivoTotal 2024-04-07  2.595990e+10
# 1082650  ECOR3  PassivoTotal 2024-04-08  2.595990e+10
# 1082651  ECOR3  PassivoTotal 2024-04-09  2.595990e+10
# 1082652  ECOR3  PassivoTotal 2024-04-10  2.595990e+10
#
# [4769 rows x 4 columns]

# %%
params = { 'item': 'PatrimonioLiquido', 'tipoPeriodo': 'TRIMESTRAL' }

endpoint = URL_BASE + '/bolsa/b3/avista/itens-contabeis/point-in-time/arquivos'
response = requests.get(endpoint, headers=headers, params=params)
print(response.json())
# Out:
# {'link': 'https://fintz-dagster.s3.amazonaws.com/fontes/cvm/dfin/files/dfin_files/PatrimonioLiquido.parquet?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=ASIAV2KWAOXUPWVZIM33%2F20240410%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240410T105453Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEPP%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMiJGMEQCIHEcG2W%2Fbd1rB8M6UEu50ILnhY2MbVTRj%2FeuiHJrTEomAiBzBTNTmgmsKWp5LjzneeCsKr7ccPbVwbCU7fvlz8m%2FDSruAggsEAEaDDQwMDE0OTIxNDY5NiIMlTEvDVnhuXup0YDPKssCWB0qLeLWY6Behyux47Jzq8I%2BlwV3aYz4hvReZ5ABhb4tUJ7s5PWJwDzOt8eKA4O5BM3czlPhki5yLIdJJkIt7pCVYsCh8bJiEaolVZQyOo7A%2FaeaS9hvmQxw0ta7tW4Y9kWvL6OKkLxr50nz2GB2PDgSEU9lX%2BZLrK3iXPTALIKqBO%2BDMw353ZzOr66Q%2B3x2X%2FY9A1%2BseheDfRE6Bo2rAcfg%2BzICIM3SERy020Spa8hTwHg%2Fu7Nuu47XZDkY4JCuefeULFC16i4vIMjt3XKGB3vrDvRv1pOEs2Wp7DSkMFDrekwCjWSEhW0QqbckBpoKow9%2BJNfSb0M94iOKi3zqn8ecx5ulQhymHAIqx2Uu9lYWjtUXQGWxGs99NfIt71A8KdmH4jTrsbBVybu7ADuUrN9rQUdvr5R%2FvXFkp1liWDObTlPAozgTgq%2B5Vz
# ...

# %%
patrimonio_liquido = pd.read_parquet('PatrimonioLiquido.parquet')

# %%
patrimonio_liquido[patrimonio_liquido['ticker']=='ABEV3']
# Out:
#       ticker               item       data         valor
# 7452   ABEV3  PatrimonioLiquido 2013-10-31  3.968560e+10
# 7453   ABEV3  PatrimonioLiquido 2013-11-01  3.968560e+10
# 7454   ABEV3  PatrimonioLiquido 2013-11-02  3.968560e+10
# 7455   ABEV3  PatrimonioLiquido 2013-11-03  3.968560e+10
# 7456   ABEV3  PatrimonioLiquido 2013-11-04  3.968560e+10
# ...      ...                ...        ...           ...
# 11262  ABEV3  PatrimonioLiquido 2024-04-06  8.014380e+10
# 11263  ABEV3  PatrimonioLiquido 2024-04-07  8.014380e+10
# 11264  ABEV3  PatrimonioLiquido 2024-04-08  8.014380e+10
# 11265  ABEV3  PatrimonioLiquido 2024-04-09  8.014380e+10
# 11266  ABEV3  PatrimonioLiquido 2024-04-10  8.014380e+10
#
# [3815 rows x 4 columns]

# %% [markdown]
# DOWNLOAD DE INDICADORES FUNDAMENTALISTAS

# %%
params = { 'indicador': 'ROE' }

endpoint = URL_BASE + '/bolsa/b3/avista/indicadores/point-in-time/arquivos'
response = requests.get(endpoint, headers=headers, params=params)
print(response.json())
# Out:
# {'link': 'https://fintz-dagster.s3.amazonaws.com/fontes/cvm/dfin/files/indicadores_files/ROE.parquet?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=ASIAV2KWAOXUBH5NN6MF%2F20240410%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240410T084840Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEPH%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMiJHMEUCICRuoMjZ3t%2FFVFpfE4gpenB%2FL9X%2BfdeTsXfoGXX1IZH0AiEAuHPKWiXLMYZVz2xl2DeqZAZJ3o%2B5t25UBYpOm5AgyCQq7gIIKhABGgw0MDAxNDkyMTQ2OTYiDACJu8HjD70%2B4EdfKCrLAgwLBttbC3UD535oa05pxhtmqgh2jF0JtqTkEFE7ktYVKlAc7kngv14UJHMdtJOcK4XJc7igQdblh3nLuVm16F6QTNTBjoS0ffADbejfC3%2BE4elZ%2F9AUy8YAU4bY1tRAvNLfimd7DUsYx7gnGVtUew%2BmEtDMTVGauDFsr883sQRdXLReta2g5cuPfTvYhK42UREC%2FdJVNZR9TKfpmTbawxnai6TyJSmovL6g4NJZinNk469kRq4xnsxo9HvaVnG3xVPd7OT8hE%2F9BYGa7YlzIdrDw3MBKxorhg4SdvBjYZ7lv4hE89DxobdtVSVoS0qyNMHu5bznSHRtFr%2FJDWVyPxosHnR6kjlPG7fUSgItl%2B9nTAXNLmSVMsC3GTxHVl3%2FrsvL3jNrh9dL97onRd2B924qLNsDiZVh2XOoh7lzGHljKE2bAMAv%2Bh%2FGguIw4qTZs
# ...

# %%
roe = pd.read_parquet('ROE.parquet')

# %%
roe
# Out:
#         ticker indicador       data     valor
# 0        AALR3       ROE 2016-12-04  0.028501
# 1        AALR3       ROE 2016-12-05  0.028501
# 2        AALR3       ROE 2016-12-06  0.028501
# 3        AALR3       ROE 2016-12-07  0.028501
# 4        AALR3       ROE 2016-12-08  0.028501
# ...        ...       ...        ...       ...
# 2858253  ZAMP3       ROE 2024-04-06 -0.070193
# 2858254  ZAMP3       ROE 2024-04-07 -0.070193
# 2858255  ZAMP3       ROE 2024-04-08 -0.070193
# 2858256  ZAMP3       ROE 2024-04-09 -0.070193
# 2858257  ZAMP3       ROE 2024-04-10 -0.070193
#
# [2858258 rows x 4 columns]

# %%
params = { 'indicador': 'P_L' }

endpoint = URL_BASE + '/bolsa/b3/avista/indicadores/point-in-time/arquivos'
response = requests.get(endpoint, headers=headers, params=params)
print(response.json())
# Out:
# {'link': 'https://fintz-dagster.s3.amazonaws.com/fontes/cvm/dfin/files/indicadores_files/P_L.parquet?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=ASIAV2KWAOXUBH5NN6MF%2F20240410%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240410T085209Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEPH%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMiJHMEUCICRuoMjZ3t%2FFVFpfE4gpenB%2FL9X%2BfdeTsXfoGXX1IZH0AiEAuHPKWiXLMYZVz2xl2DeqZAZJ3o%2B5t25UBYpOm5AgyCQq7gIIKhABGgw0MDAxNDkyMTQ2OTYiDACJu8HjD70%2B4EdfKCrLAgwLBttbC3UD535oa05pxhtmqgh2jF0JtqTkEFE7ktYVKlAc7kngv14UJHMdtJOcK4XJc7igQdblh3nLuVm16F6QTNTBjoS0ffADbejfC3%2BE4elZ%2F9AUy8YAU4bY1tRAvNLfimd7DUsYx7gnGVtUew%2BmEtDMTVGauDFsr883sQRdXLReta2g5cuPfTvYhK42UREC%2FdJVNZR9TKfpmTbawxnai6TyJSmovL6g4NJZinNk469kRq4xnsxo9HvaVnG3xVPd7OT8hE%2F9BYGa7YlzIdrDw3MBKxorhg4SdvBjYZ7lv4hE89DxobdtVSVoS0qyNMHu5bznSHRtFr%2FJDWVyPxosHnR6kjlPG7fUSgItl%2B9nTAXNLmSVMsC3GTxHVl3%2FrsvL3jNrh9dL97onRd2B924qLNsDiZVh2XOoh7lzGHljKE2bAMAv%2Bh%2FGguIw4qTZs
# ...

# %%
p_l = pd.read_parquet('P_L.parquet')

# %%
p_l
# Out:
#         ticker indicador       data      valor
# 0        AALR3       P_L 2016-12-04  88.376521
# 1        AALR3       P_L 2016-12-05  87.598137
# 2        AALR3       P_L 2016-12-06  86.700002
# 3        AALR3       P_L 2016-12-07  86.220996
# 4        AALR3       P_L 2016-12-08  86.220996
# ...        ...       ...        ...        ...
# 2605317  ZAMP3       P_L 2024-04-06  -8.444241
# 2605318  ZAMP3       P_L 2024-04-07  -8.444241
# 2605319  ZAMP3       P_L 2024-04-08  -8.782011
# 2605320  ZAMP3       P_L 2024-04-09  -9.176075
# 2605321  ZAMP3       P_L 2024-04-10  -9.176075
#
# [2605322 rows x 4 columns]

# %%
params = { 'indicador': 'P_VP' }

endpoint = URL_BASE + '/bolsa/b3/avista/indicadores/point-in-time/arquivos'
response = requests.get(endpoint, headers=headers, params=params)
print(response.json())
# Out:
# {'link': 'https://fintz-dagster.s3.amazonaws.com/fontes/cvm/dfin/files/indicadores_files/P_VP.parquet?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=ASIAV2KWAOXUBH5NN6MF%2F20240410%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240410T085404Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEPH%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMiJHMEUCICRuoMjZ3t%2FFVFpfE4gpenB%2FL9X%2BfdeTsXfoGXX1IZH0AiEAuHPKWiXLMYZVz2xl2DeqZAZJ3o%2B5t25UBYpOm5AgyCQq7gIIKhABGgw0MDAxNDkyMTQ2OTYiDACJu8HjD70%2B4EdfKCrLAgwLBttbC3UD535oa05pxhtmqgh2jF0JtqTkEFE7ktYVKlAc7kngv14UJHMdtJOcK4XJc7igQdblh3nLuVm16F6QTNTBjoS0ffADbejfC3%2BE4elZ%2F9AUy8YAU4bY1tRAvNLfimd7DUsYx7gnGVtUew%2BmEtDMTVGauDFsr883sQRdXLReta2g5cuPfTvYhK42UREC%2FdJVNZR9TKfpmTbawxnai6TyJSmovL6g4NJZinNk469kRq4xnsxo9HvaVnG3xVPd7OT8hE%2F9BYGa7YlzIdrDw3MBKxorhg4SdvBjYZ7lv4hE89DxobdtVSVoS0qyNMHu5bznSHRtFr%2FJDWVyPxosHnR6kjlPG7fUSgItl%2B9nTAXNLmSVMsC3GTxHVl3%2FrsvL3jNrh9dL97onRd2B924qLNsDiZVh2XOoh7lzGHljKE2bAMAv%2Bh%2FGguIw4qTZ
# ...

# %%
p_vp = pd.read_parquet('P_VP.parquet')

# %%
p_vp[p_vp['ticker']=='VALE3']
# Out:
#         ticker indicador       data     valor
# 2653947  VALE3      P_VP 2011-02-24  2.560269
# 2653948  VALE3      P_VP 2011-02-25  2.569032
# 2653949  VALE3      P_VP 2011-02-26  2.569032
# 2653950  VALE3      P_VP 2011-02-27  2.569032
# 2653951  VALE3      P_VP 2011-02-28  2.596706
# ...        ...       ...        ...       ...
# 2658737  VALE3      P_VP 2024-04-06  1.366566
# 2658738  VALE3      P_VP 2024-04-07  1.366566
# 2658739  VALE3      P_VP 2024-04-08  1.441176
# 2658740  VALE3      P_VP 2024-04-09  1.431564
# 2658741  VALE3      P_VP 2024-04-10  1.431564
#
# [4795 rows x 4 columns]

# %%
params = { 'indicador': 'DividendYield' }

endpoint = URL_BASE + '/bolsa/b3/avista/indicadores/point-in-time/arquivos'
response = requests.get(endpoint, headers=headers, params=params)
print(response.json())
# Out:
# {'link': 'https://fintz-dagster.s3.amazonaws.com/fontes/cvm/dfin/files/indicadores_files/DividendYield.parquet?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=ASIAV2KWAOXUBH5NN6MF%2F20240410%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240410T085540Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEPH%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMiJHMEUCICRuoMjZ3t%2FFVFpfE4gpenB%2FL9X%2BfdeTsXfoGXX1IZH0AiEAuHPKWiXLMYZVz2xl2DeqZAZJ3o%2B5t25UBYpOm5AgyCQq7gIIKhABGgw0MDAxNDkyMTQ2OTYiDACJu8HjD70%2B4EdfKCrLAgwLBttbC3UD535oa05pxhtmqgh2jF0JtqTkEFE7ktYVKlAc7kngv14UJHMdtJOcK4XJc7igQdblh3nLuVm16F6QTNTBjoS0ffADbejfC3%2BE4elZ%2F9AUy8YAU4bY1tRAvNLfimd7DUsYx7gnGVtUew%2BmEtDMTVGauDFsr883sQRdXLReta2g5cuPfTvYhK42UREC%2FdJVNZR9TKfpmTbawxnai6TyJSmovL6g4NJZinNk469kRq4xnsxo9HvaVnG3xVPd7OT8hE%2F9BYGa7YlzIdrDw3MBKxorhg4SdvBjYZ7lv4hE89DxobdtVSVoS0qyNMHu5bznSHRtFr%2FJDWVyPxosHnR6kjlPG7fUSgItl%2B9nTAXNLmSVMsC3GTxHVl3%2FrsvL3jNrh9dL97onRd2B924qLNsDiZVh2XOoh7lzGHljKE2bAMAv%2Bh%2F
# ...

# %%
dy = pd.read_parquet('DividendYield.parquet')

# %%
dy[dy['ticker']=='SANB11']
# Out:
#          ticker      indicador       data     valor
# 1863279  SANB11  DividendYield 2010-01-04  0.010535
# 1863280  SANB11  DividendYield 2010-01-05  0.010434
# 1863281  SANB11  DividendYield 2010-01-06  0.010486
# 1863282  SANB11  DividendYield 2010-01-07  0.010561
# 1863283  SANB11  DividendYield 2010-01-08  0.010670
# ...         ...            ...        ...       ...
# 1868485  SANB11  DividendYield 2024-04-06  0.057437
# 1868486  SANB11  DividendYield 2024-04-07  0.057437
# 1868487  SANB11  DividendYield 2024-04-08  0.057112
# 1868488  SANB11  DividendYield 2024-04-09  0.057031
# 1868489  SANB11  DividendYield 2024-04-10  0.057031
#
# [5211 rows x 4 columns]

# %%
params = { 'indicador': 'ROIC' }

endpoint = URL_BASE + '/bolsa/b3/avista/indicadores/point-in-time/arquivos'
response = requests.get(endpoint, headers=headers, params=params)
print(response.json())
# Out:
# {'link': 'https://fintz-dagster.s3.amazonaws.com/fontes/cvm/dfin/files/indicadores_files/ROIC.parquet?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=ASIAV2KWAOXUBH5NN6MF%2F20240410%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240410T085842Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEPH%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMiJHMEUCICRuoMjZ3t%2FFVFpfE4gpenB%2FL9X%2BfdeTsXfoGXX1IZH0AiEAuHPKWiXLMYZVz2xl2DeqZAZJ3o%2B5t25UBYpOm5AgyCQq7gIIKhABGgw0MDAxNDkyMTQ2OTYiDACJu8HjD70%2B4EdfKCrLAgwLBttbC3UD535oa05pxhtmqgh2jF0JtqTkEFE7ktYVKlAc7kngv14UJHMdtJOcK4XJc7igQdblh3nLuVm16F6QTNTBjoS0ffADbejfC3%2BE4elZ%2F9AUy8YAU4bY1tRAvNLfimd7DUsYx7gnGVtUew%2BmEtDMTVGauDFsr883sQRdXLReta2g5cuPfTvYhK42UREC%2FdJVNZR9TKfpmTbawxnai6TyJSmovL6g4NJZinNk469kRq4xnsxo9HvaVnG3xVPd7OT8hE%2F9BYGa7YlzIdrDw3MBKxorhg4SdvBjYZ7lv4hE89DxobdtVSVoS0qyNMHu5bznSHRtFr%2FJDWVyPxosHnR6kjlPG7fUSgItl%2B9nTAXNLmSVMsC3GTxHVl3%2FrsvL3jNrh9dL97onRd2B924qLNsDiZVh2XOoh7lzGHljKE2bAMAv%2Bh%2FGguIw4qTZ
# ...

# %%
roic = pd.read_parquet('ROIC.parquet')

# %%
roic[roic['ticker']=='WEGE3']
# Out:
#         ticker indicador       data     valor
# 2398193  WEGE3      ROIC 2011-10-26  0.068559
# 2398194  WEGE3      ROIC 2011-10-27  0.068559
# 2398195  WEGE3      ROIC 2011-10-28  0.068559
# 2398196  WEGE3      ROIC 2011-10-29  0.068559
# 2398197  WEGE3      ROIC 2011-10-30  0.068559
# ...        ...       ...        ...       ...
# 2402739  WEGE3      ROIC 2024-04-06  0.277380
# 2402740  WEGE3      ROIC 2024-04-07  0.277380
# 2402741  WEGE3      ROIC 2024-04-08  0.277380
# 2402742  WEGE3      ROIC 2024-04-09  0.277380
# 2402743  WEGE3      ROIC 2024-04-10  0.277380
#
# [4551 rows x 4 columns]

# %%
params = { 'indicador': 'VPA' }

endpoint = URL_BASE + '/bolsa/b3/avista/indicadores/point-in-time/arquivos'
response = requests.get(endpoint, headers=headers, params=params)
print(response.json())
# Out:
# {'link': 'https://fintz-dagster.s3.amazonaws.com/fontes/cvm/dfin/files/indicadores_files/VPA.parquet?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=ASIAV2KWAOXUBH5NN6MF%2F20240410%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240410T090044Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEPH%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMiJHMEUCICRuoMjZ3t%2FFVFpfE4gpenB%2FL9X%2BfdeTsXfoGXX1IZH0AiEAuHPKWiXLMYZVz2xl2DeqZAZJ3o%2B5t25UBYpOm5AgyCQq7gIIKhABGgw0MDAxNDkyMTQ2OTYiDACJu8HjD70%2B4EdfKCrLAgwLBttbC3UD535oa05pxhtmqgh2jF0JtqTkEFE7ktYVKlAc7kngv14UJHMdtJOcK4XJc7igQdblh3nLuVm16F6QTNTBjoS0ffADbejfC3%2BE4elZ%2F9AUy8YAU4bY1tRAvNLfimd7DUsYx7gnGVtUew%2BmEtDMTVGauDFsr883sQRdXLReta2g5cuPfTvYhK42UREC%2FdJVNZR9TKfpmTbawxnai6TyJSmovL6g4NJZinNk469kRq4xnsxo9HvaVnG3xVPd7OT8hE%2F9BYGa7YlzIdrDw3MBKxorhg4SdvBjYZ7lv4hE89DxobdtVSVoS0qyNMHu5bznSHRtFr%2FJDWVyPxosHnR6kjlPG7fUSgItl%2B9nTAXNLmSVMsC3GTxHVl3%2FrsvL3jNrh9dL97onRd2B924qLNsDiZVh2XOoh7lzGHljKE2bAMAv%2Bh%2FGguIw4qTZs
# ...

# %%
vpa = pd.read_parquet('VPA.parquet')

# %%
vpa[vpa['ticker']=='BBDC4']
# Out:
#        ticker indicador       data      valor
# 225452  BBDC4       VPA 2011-04-15  13.375509
# 225453  BBDC4       VPA 2011-04-16  13.375509
# 225454  BBDC4       VPA 2011-04-17  13.375509
# 225455  BBDC4       VPA 2011-04-18  13.375509
# 225456  BBDC4       VPA 2011-04-19  13.375509
# ...       ...       ...        ...        ...
# 230192  BBDC4       VPA 2024-04-06  15.693615
# 230193  BBDC4       VPA 2024-04-07  15.693615
# 230194  BBDC4       VPA 2024-04-08  15.693615
# 230195  BBDC4       VPA 2024-04-09  15.693615
# 230196  BBDC4       VPA 2024-04-10  15.693615
#
# [4745 rows x 4 columns]

# %%
params = { 'indicador': 'LPA' }

endpoint = URL_BASE + '/bolsa/b3/avista/indicadores/point-in-time/arquivos'
response = requests.get(endpoint, headers=headers, params=params)
print(response.json())
# Out:
# {'link': 'https://fintz-dagster.s3.amazonaws.com/fontes/cvm/dfin/files/indicadores_files/LPA.parquet?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=ASIAV2KWAOXUBH5NN6MF%2F20240410%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240410T090106Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEPH%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMiJHMEUCICRuoMjZ3t%2FFVFpfE4gpenB%2FL9X%2BfdeTsXfoGXX1IZH0AiEAuHPKWiXLMYZVz2xl2DeqZAZJ3o%2B5t25UBYpOm5AgyCQq7gIIKhABGgw0MDAxNDkyMTQ2OTYiDACJu8HjD70%2B4EdfKCrLAgwLBttbC3UD535oa05pxhtmqgh2jF0JtqTkEFE7ktYVKlAc7kngv14UJHMdtJOcK4XJc7igQdblh3nLuVm16F6QTNTBjoS0ffADbejfC3%2BE4elZ%2F9AUy8YAU4bY1tRAvNLfimd7DUsYx7gnGVtUew%2BmEtDMTVGauDFsr883sQRdXLReta2g5cuPfTvYhK42UREC%2FdJVNZR9TKfpmTbawxnai6TyJSmovL6g4NJZinNk469kRq4xnsxo9HvaVnG3xVPd7OT8hE%2F9BYGa7YlzIdrDw3MBKxorhg4SdvBjYZ7lv4hE89DxobdtVSVoS0qyNMHu5bznSHRtFr%2FJDWVyPxosHnR6kjlPG7fUSgItl%2B9nTAXNLmSVMsC3GTxHVl3%2FrsvL3jNrh9dL97onRd2B924qLNsDiZVh2XOoh7lzGHljKE2bAMAv%2Bh%2FGguIw4qTZs
# ...

# %%
lpa = pd.read_parquet('LPA.parquet')

# %%
lpa[lpa['ticker']=='PETR4']
# Out:
#         ticker indicador       data     valor
# 2012421  PETR4       LPA 2011-11-11  2.979453
# 2012422  PETR4       LPA 2011-11-12  2.979453
# 2012423  PETR4       LPA 2011-11-13  2.979453
# 2012424  PETR4       LPA 2011-11-14  2.979453
# 2012425  PETR4       LPA 2011-11-15  2.979453
# ...        ...       ...        ...       ...
# 2016951  PETR4       LPA 2024-04-06  9.552381
# 2016952  PETR4       LPA 2024-04-07  9.552381
# 2016953  PETR4       LPA 2024-04-08  9.552381
# 2016954  PETR4       LPA 2024-04-09  9.552381
# 2016955  PETR4       LPA 2024-04-10  9.552381
#
# [4535 rows x 4 columns]

# %%
params = { 'indicador': 'DividaBruta_PatrimonioLiquido' }

endpoint = URL_BASE + '/bolsa/b3/avista/indicadores/point-in-time/arquivos'
response = requests.get(endpoint, headers=headers, params=params)
print(response.json())
# Out:
# {'link': 'https://fintz-dagster.s3.amazonaws.com/fontes/cvm/dfin/files/indicadores_files/DividaBruta_PatrimonioLiquido.parquet?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=ASIAV2KWAOXUN4DXTC6I%2F20240410%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240410T112631Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEPP%2F%2F%2F%2F%2F%2F%2F%2F%2F%%2Fp5hzQ3q5dY88fF0T6ZMlKLBzvnI5FL90GwMANtAw2cF0TC%2B%2FF1pm1YvnTWfoGp%2F5HVC17X3Y1gBxkV%2Fj%2B%2F4Bnrt1lmnyUP%2FwREBIkEn0GarM0CeSJ0tWrQCqscNJbTUVahfLW8IflQec2lM4ZxMUuDLWOnKaygXTsN%2FY5q0feqzwdnyyOlSy4RxPAkdSpwMY%2BFpWOfO%2FR59ew3xz8OwwIFbaBdtEzKvBfuSO8BFmuz49yuwUD9owfg7f6gm8Rp%2FHc1ZkEBPwmQXT1FH6riVJh4BFO%2F3
# ...

# %%
divida_bruta_patrimonio_liquido = pd.read_parquet('DividaBruta_PatrimonioLiquido.parquet')

# %%
divida_bruta_patrimonio_liquido[divida_bruta_patrimonio_liquido['ticker']=='TAEE11']
# Out:
#          ticker                      indicador       data     valor
# 2404603  TAEE11  DividaBruta_PatrimonioLiquido 2011-03-28  0.614465
# 2404604  TAEE11  DividaBruta_PatrimonioLiquido 2011-03-29  0.614465
# 2404605  TAEE11  DividaBruta_PatrimonioLiquido 2011-03-30  0.614465
# 2404606  TAEE11  DividaBruta_PatrimonioLiquido 2011-03-31  0.614465
# 2404607  TAEE11  DividaBruta_PatrimonioLiquido 2011-04-01  0.614465
# ...         ...                            ...        ...       ...
# 2409361  TAEE11  DividaBruta_PatrimonioLiquido 2024-04-06  1.452641
# 2409362  TAEE11  DividaBruta_PatrimonioLiquido 2024-04-07  1.452641
# 2409363  TAEE11  DividaBruta_PatrimonioLiquido 2024-04-08  1.452641
# 2409364  TAEE11  DividaBruta_PatrimonioLiquido 2024-04-09  1.452641
# 2409365  TAEE11  DividaBruta_PatrimonioLiquido 2024-04-10  1.452641
#
# [4763 rows x 4 columns]

# %%
params = { 'indicador': 'DividaLiquida_PatrimonioLiquido' }

endpoint = URL_BASE + '/bolsa/b3/avista/indicadores/point-in-time/arquivos'
response = requests.get(endpoint, headers=headers, params=params)
print(response.json())
# Out:
# {'link': 'https://fintz-dagster.s3.amazonaws.com/fontes/cvm/dfin/files/indicadores_files/DividaLiquida_PatrimonioLiquido.parquet?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=ASIAV2KWAOXUN4DXTC6I%2F20240410%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240410T112646Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEPP%2F%2F%2F%2F%2F%2F%2F%2F%2F%%2Fp5hzQ3q5dY88fF0T6ZMlKLBzvnI5FL90GwMANtAw2cF0TC%2B%2FF1pm1YvnTWfoGp%2F5HVC17X3Y1gBxkV%2Fj%2B%2F4Bnrt1lmnyUP%2FwREBIkEn0GarM0CeSJ0tWrQCqscNJbTUVahfLW8IflQec2lM4ZxMUuDLWOnKaygXTsN%2FY5q0feqzwdnyyOlSy4RxPAkdSpwMY%2BFpWOfO%2FR59ew3xz8OwwIFbaBdtEzKvBfuSO8BFmuz49yuwUD9owfg7f6gm8Rp%2FHc1ZkEBPwmQXT1FH6riVJh4BFO%2
# ...

# %%
divida_liquida_patrimonio_liquido = pd.read_parquet('DividaLiquida_PatrimonioLiquido.parquet')

# %%
divida_liquida_patrimonio_liquido[divida_liquida_patrimonio_liquido['ticker']=='YDUQ3']
# Out:
#         ticker                        indicador       data     valor
# 2779270  YDUQ3  DividaLiquida_PatrimonioLiquido 2011-03-17 -0.266074
# 2779271  YDUQ3  DividaLiquida_PatrimonioLiquido 2011-03-18 -0.266074
# 2779272  YDUQ3  DividaLiquida_PatrimonioLiquido 2011-03-19 -0.266074
# 2779273  YDUQ3  DividaLiquida_PatrimonioLiquido 2011-03-20 -0.266074
# 2779274  YDUQ3  DividaLiquida_PatrimonioLiquido 2011-03-21 -0.266074
# ...        ...                              ...        ...       ...
# 2784039  YDUQ3  DividaLiquida_PatrimonioLiquido 2024-04-06  1.453912
# 2784040  YDUQ3  DividaLiquida_PatrimonioLiquido 2024-04-07  1.453912
# 2784041  YDUQ3  DividaLiquida_PatrimonioLiquido 2024-04-08  1.453912
# 2784042  YDUQ3  DividaLiquida_PatrimonioLiquido 2024-04-09  1.453912
# 2784043  YDUQ3  DividaLiquida_PatrimonioLiquido 2024-04-10  1.453912
#
# [4774 rows x 4 columns]

# %%
params = { 'indicador': 'DividaLiquida_EBIT' }

endpoint = URL_BASE + '/bolsa/b3/avista/indicadores/point-in-time/arquivos'
response = requests.get(endpoint, headers=headers, params=params)
print(response.json())
# Out:
# {'link': 'https://fintz-dagster.s3.amazonaws.com/fontes/cvm/dfin/files/indicadores_files/DividaLiquida_EBIT.parquet?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=ASIAV2KWAOXUN4DXTC6I%2F20240410%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240410T112705Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEPP%2F%2F%2F%2F%2F%2F%2F%2F%2F%%2Fp5hzQ3q5dY88fF0T6ZMlKLBzvnI5FL90GwMANtAw2cF0TC%2B%2FF1pm1YvnTWfoGp%2F5HVC17X3Y1gBxkV%2Fj%2B%2F4Bnrt1lmnyUP%2FwREBIkEn0GarM0CeSJ0tWrQCqscNJbTUVahfLW8IflQec2lM4ZxMUuDLWOnKaygXTsN%2FY5q0feqzwdnyyOlSy4RxPAkdSpwMY%2BFpWOfO%2FR59ew3xz8OwwIFbaBdtEzKvBfuSO8BFmuz49yuwUD9owfg7f6gm8Rp%2FHc1ZkEBPwmQXT1FH6riVJh4BFO%2F36IJGsVTSsi%
# ...

# %%
divida_liquida_ebit = pd.read_parquet('DividaLiquida_EBIT.parquet')

# %%
divida_liquida_ebit[divida_liquida_ebit['ticker']=='PSSA3']
# Out:
#         ticker           indicador       data       valor
# 1876151  PSSA3  DividaLiquida_EBIT 2011-11-01 -304.585066
# 1876152  PSSA3  DividaLiquida_EBIT 2011-11-02 -304.585066
# 1876153  PSSA3  DividaLiquida_EBIT 2011-11-03 -304.585066
# 1876154  PSSA3  DividaLiquida_EBIT 2011-11-04 -304.585066
# 1876155  PSSA3  DividaLiquida_EBIT 2011-11-05 -304.585066
# ...        ...                 ...        ...         ...
# 1880691  PSSA3  DividaLiquida_EBIT 2024-04-06   -4.279559
# 1880692  PSSA3  DividaLiquida_EBIT 2024-04-07   -4.279559
# 1880693  PSSA3  DividaLiquida_EBIT 2024-04-08   -4.279559
# 1880694  PSSA3  DividaLiquida_EBIT 2024-04-09   -4.279559
# 1880695  PSSA3  DividaLiquida_EBIT 2024-04-10   -4.279559
#
# [4545 rows x 4 columns]

# %%
params = { 'indicador': 'DividaLiquida_EBITDA' }

endpoint = URL_BASE + '/bolsa/b3/avista/indicadores/point-in-time/arquivos'
response = requests.get(endpoint, headers=headers, params=params)
print(response.json())
# Out:
# {'link': 'https://fintz-dagster.s3.amazonaws.com/fontes/cvm/dfin/files/indicadores_files/DividaLiquida_EBITDA.parquet?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=ASIAV2KWAOXUFZ5O4OGJ%2F20240410%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240410T114914Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEPT%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMiJHMEUCIQCB1aiHZRgQg%2Bm1kdHfxTZWZ3Z%2F%2FDc32EkBwTrUfRcE8QIgC26UfNvzhUDTGJbjAKldXi1Nn2kJlumszxYknhk0rMQq7gIILRABGgw0MDAxNDkyMTQ2OTYiDGdOnrNI3bNn8Kwm8yrLAt7y4%2FNr0KQ15WRa1%2BoeKxA%2F81zheN9KYou%2B7xbrLj0OwblUNKdhEBvcwK%2FGwbc7bZeVWVzw%2Bx%2FeF5QvvP%2FXRJCaqq8gFSrpmXUWPxboCOGsk9SL294eJl0DWOyVbA3RHfDZUEatD1G511ReKivXwAcgMgrT9KGJ0QAPSgSYbmgjEP805qYszws0S8Xx8OJ5axS8ALJdSq3VNNCVPqfaVSSPQGL58SUlytt1wPLt5wOUZAKFCnlzTs7G1A8jDxZ0hEGSZJj2LNOUarBBlIXzdWj%2BpAPdmKtImCvi1B74f%2FYgT5DAfj7SbJmqwA2E%2FXzspdWSI7FHYsKpdk7Mu0Pu5pYGEUYn%2F1M4fSNhDVluc0KEd%2BRpTHtOw9grmr8aR092nw9GAB9f%2FCj9NNK72tTxMSmY176KL5AoQ30QlBoMKmmt
# ...

# %%
divida_liquida_ebitda = pd.read_parquet('DividaLiquida_EBITDA.parquet')

# %%
divida_liquida_ebitda[divida_liquida_ebitda['ticker']=='MRVE3']
# Out:
#         ticker             indicador       data      valor
# 1600804  MRVE3  DividaLiquida_EBITDA 2011-11-14   1.534990
# 1600805  MRVE3  DividaLiquida_EBITDA 2011-11-15   1.534990
# 1600806  MRVE3  DividaLiquida_EBITDA 2011-11-16   1.534990
# 1600807  MRVE3  DividaLiquida_EBITDA 2011-11-17   1.534990
# 1600808  MRVE3  DividaLiquida_EBITDA 2011-11-18   1.534990
# ...        ...                   ...        ...        ...
# 1605331  MRVE3  DividaLiquida_EBITDA 2024-04-06  25.854923
# 1605332  MRVE3  DividaLiquida_EBITDA 2024-04-07  25.854923
# 1605333  MRVE3  DividaLiquida_EBITDA 2024-04-08  25.854923
# 1605334  MRVE3  DividaLiquida_EBITDA 2024-04-09  25.854923
# 1605335  MRVE3  DividaLiquida_EBITDA 2024-04-10  25.854923
#
# [4532 rows x 4 columns]

# %%
params = { 'indicador': 'ValorDeMercado' }

endpoint = URL_BASE + '/bolsa/b3/avista/indicadores/point-in-time/arquivos'
response = requests.get(endpoint, headers=headers, params=params)
print(response.json())
# Out:
# {'link': 'https://fintz-dagster.s3.amazonaws.com/fontes/cvm/dfin/files/indicadores_files/ValorDeMercado.parquet?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=ASIAV2KWAOXUB5RR2WW7%2F20240410%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240410T112737Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEPP%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMiJIMEYCIQDv79njho5hw8k4NlvRxCvrgJvwbqt5%2Faq9W%2FT5Mje%2B%2BQIhAOuy7VAts9wHJ%2FuItW0MBBZ%2BbvCcBMV%2B7zvd1%2B%2BhfIbeKu4CCC0QARoMNDAwMTQ5MjE0Njk2IgwCIOqSFRSsPtAf5x8qywITylAJEUHT15qjcmq1uibSR6S85DwYlfRNTiF21HBDbmjPEtfnJUHtajxOKYxtgRZMSYQmb69vsgaOAz8F9ck4YTj8kRBqsY2enumWKnpONSy3M5zxuNF0bMjEWYXrn96gPa12DClWMkAosP0isQMLWeXbCuMGMmUIvwyHShqaJ%2F4Nf1%2BsQtobh1ANhzq00GBNrevVBCvm1o5dxUn67qa3n9pBetR7BWk2FX7k1BPnhXhKMx8VU8MCgYKJVFL0V7ljZtqZB1ZWFRmGb5r5UkKBhL%2FKcMbjO%2F21IIK2liHHQGES%2ByIlFTT%2FLwg66Od2A7IhpQzSksOY84Lcef3DDe0tu5WG9BiNDxD%2FcKOWD4LVtAYhy3DGj4ZYCSh3UeZ%2BaVw2npKRqQos16uqWBonoT%2FKhVP2NNS2BNET7iZQRfzJGIUY
# ...

# %%
valor_de_mercado = pd.read_parquet('ValorDeMercado.parquet')

# %%
valor_de_mercado[valor_de_mercado['ticker']=='CSMG3']
# Out:
#        ticker       indicador       data         valor
# 825637  CSMG3  ValorDeMercado 2011-01-03  3.419768e+09
# 825638  CSMG3  ValorDeMercado 2011-01-04  3.343671e+09
# 825639  CSMG3  ValorDeMercado 2011-01-05  3.335600e+09
# 825640  CSMG3  ValorDeMercado 2011-01-06  3.366731e+09
# 825641  CSMG3  ValorDeMercado 2011-01-07  3.355201e+09
# ...       ...             ...        ...           ...
# 830479  CSMG3  ValorDeMercado 2024-04-06  8.049956e+09
# 830480  CSMG3  ValorDeMercado 2024-04-07  8.049956e+09
# 830481  CSMG3  ValorDeMercado 2024-04-08  8.126007e+09
# 830482  CSMG3  ValorDeMercado 2024-04-09  8.266700e+09
# 830483  CSMG3  ValorDeMercado 2024-04-10  8.266700e+09
#
# [4847 rows x 4 columns]

# %%
params = { 'indicador': 'EV' }

endpoint = URL_BASE + '/bolsa/b3/avista/indicadores/point-in-time/arquivos'
response = requests.get(endpoint, headers=headers, params=params)
print(response.json())
# Out:
# {'link': 'https://fintz-dagster.s3.amazonaws.com/fontes/cvm/dfin/files/indicadores_files/EV.parquet?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=ASIAV2KWAOXUB5RR2WW7%2F20240410%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240410T112755Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEPP%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMiJIMEYCIQDv79njho5hw8k4NlvRxCvrgJvwbqt5%2Faq9W%2FT5Mje%2B%2BQIhAOuy7VAts9wHJ%2FuItW0MBBZ%2BbvCcBMV%2B7zvd1%2B%2BhfIbeKu4CCC0QARoMNDAwMTQ5MjE0Njk2IgwCIOqSFRSsPtAf5x8qywITylAJEUHT15qjcmq1uibSR6S85DwYlfRNTiF21HBDbmjPEtfnJUHtajxOKYxtgRZMSYQmb69vsgaOAz8F9ck4YTj8kRBqsY2enumWKnpONSy3M5zxuNF0bMjEWYXrn96gPa12DClWMkAosP0isQMLWeXbCuMGMmUIvwyHShqaJ%2F4Nf1%2BsQtobh1ANhzq00GBNrevVBCvm1o5dxUn67qa3n9pBetR7BWk2FX7k1BPnhXhKMx8VU8MCgYKJVFL0V7ljZtqZB1ZWFRmGb5r5UkKBhL%2FKcMbjO%2F21IIK2liHHQGES%2ByIlFTT%2FLwg66Od2A7IhpQzSksOY84Lcef3DDe0tu5WG9BiNDxD%2FcKOWD4LVtAYhy3DGj4ZYCSh3UeZ%2BaVw2npKRqQos16uqWBonoT%2FKhVP2NNS2BNET7iZQRfzJGIUY%2BwJwqljk78
# ...

# %%
ev = pd.read_parquet('EV.parquet')

# %%
ev[ev['ticker']=='SBSP3']
# Out:
#         ticker indicador       data         valor
# 2021275  SBSP3        EV 2011-03-29  1.655084e+10
# 2021276  SBSP3        EV 2011-03-30  1.665337e+10
# 2021277  SBSP3        EV 2011-03-31  1.698376e+10
# 2021278  SBSP3        EV 2011-04-01  1.706122e+10
# 2021279  SBSP3        EV 2011-04-02  1.706122e+10
# ...        ...       ...        ...           ...
# 2026032  SBSP3        EV 2024-04-06  7.379530e+10
# 2026033  SBSP3        EV 2024-04-07  7.379530e+10
# 2026034  SBSP3        EV 2024-04-08  7.402770e+10
# 2026035  SBSP3        EV 2024-04-09  7.434211e+10
# 2026036  SBSP3        EV 2024-04-10  7.434211e+10
#
# [4762 rows x 4 columns]
